# %% [markdown]
# # 06 — DiffDock: Molecular Docking Screening
#
# **Goal:** Dock known ERAP2 inhibitors (DG013A, bestatin) against predicted structures
# to validate that our structures produce realistic binding poses.
#
# Then screen a small library of aminopeptidase inhibitors from DrugBank.
#
# **Run on:** Google Colab (T4/V100 sufficient, 8-12GB VRAM)
#
# ## References
# - DiffDock: https://github.com/gcorso/DiffDock
# - ERAP2 inhibitor DG013A: Zervoudi et al. 2013 PNAS

# %%
# Install DiffDock
# !git clone https://github.com/gcorso/DiffDock.git
# %cd DiffDock
# !pip install -q -e .
# !pip install -q rdkit-pypi prody

# %%
# TODO: Upload ERAP2 PDB from notebook 05
# TODO: Get DG013A SMILES from PubChem or ChEMBL
# TODO: Get bestatin SMILES (known aminopeptidase inhibitor)

ERAP2_PDB = "erap2_wt_alphafold.pdb"  # or esmfold output

# DG013A — ERAP2-specific inhibitor
DG013A_SMILES = ""  # TODO: fetch from PubChem

# Bestatin — broad aminopeptidase inhibitor (DrugBank DB00560)
BESTATIN_SMILES = "CC(O)C(=O)NC(CC1=CC=CC=C1)C(O)=O"

print("Upload ERAP2 PDB and set DG013A SMILES to proceed.")

# %%
# Run DiffDock docking
# See DiffDock README for exact inference commands
# Basic usage:
# python -m inference --protein_path ERAP2.pdb --ligand SMILES --out_dir results/
print("DiffDock docking — configure after uploading structures and ligands")
